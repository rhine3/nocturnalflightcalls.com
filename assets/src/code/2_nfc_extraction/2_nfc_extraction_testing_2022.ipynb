# %% [markdown]
# # NFC extraction testing, part 1
#
# Previous scripts found correspondences between annotation files and audio files, and roughly determined the durations (determined using annotation lengths) and frequency limits (determined by manually guessing) of each species.
#
# This file tests extracting audio clips and creating spectrograms. After creating good-enough spectrogram extraction in this file I transferred the code to `2_extraction.py` and ran it on the cluster.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
import pandas as pd
from pathlib import Path
import random

# %% [markdown]
# Load the document which describes the upper and lower frequency limits for bandpassing as well as the approximate duration of the call

# %%
freq_limits = pd.read_csv("freq_limits.csv")
freq_limits.head()
# Out:
#    code  low_freq  high_freq  duration
# 0  ALFL       0.1       5000      0.05
# 1  AMGO    5000.0      11024      0.05
# 2  AMGP       0.1       5000      0.15
# 3  AMOY       0.1       5000      0.10
# 4  AMPI    5000.0      11024      0.05

# %% [markdown]
# Load the table which describes the pairings between annotation files and audio files

# %%
tables_to_filenames = pd.read_csv("annotation_audio_pairs.csv", index_col='annotation_file').to_dict()['audio_file']

# %% [markdown]
# Create spectrograms

# %%
# Spectrogram creation parameters
#sample_rate=22050
window_samples = 256
window_type = 'blackman'
decibel_limits = (-80, 0)

# Denoising parameters
#denoise=True
#quantile=0.8
bandpass = True
order = 4

# How many spectrograms to create and where to save them
max_num_examples = 30
create_audio = True
save_audio = True
save_spectrogram = True

def freq_reformatter(tick_val_hertz, pos):
    """
    Input: float value in Hertz, e.g. 10000.0
    Output: formatted string in kHz, e.g. '10'
    """
    val_khz = tick_val_hertz/1000
    str_format = "%.0f" % val_khz
    if len(str_format) < 2:
        str_format = str_format + '  '
    return str_format


def sec_reformatter(tick_val_sec, pos):
    """
    Input: float value in seconds, e.g. 0.15
    Output: formatted string in milliseconds, e.g. '150'
    """
    val_ms = tick_val_sec*1000
    return "%.0f" % val_ms
    

def save_spectrogram(s, filename, duration, save=True):
    """Create and save an NFC spectrogram
    
    Inputs:
        s: opensoundscape.spectrogram.Spectrogram object
        filename: where to save the file
        duration: duration of the spectrogram
        save: whether or not to save the file
    """
    plt.subplots(figsize=(duration*30, 5))
    plot = s.plot(inline=False)
    s.plot(inline=False)
    ax = plt.gca()
    ax.set_ylabel("")
    ax.set_xlabel("")
    ax.tick_params(axis="y", direction="in", pad=-25, length=5, labelsize=15)
    ax.tick_params(axis="x", direction="in", pad=-20, length=5, labelsize=15)
    
    ax.set_xticks(np.arange(0, duration, 0.05)[1:])
    ax.set_yticks([2000, 4000, 6000, 8000, 10000])
    
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(sec_reformatter))
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(freq_reformatter))
    if save:
        plt.savefig(filename, bbox_inches='tight', pad_inches=0)
    else:
        plt.show()
    plt.close()

num_examples_per_sp = {}


# Loop through all the files
random.seed(42)
keys = list(tables_to_filenames.keys()) 
random.shuffle(keys) # Randomize which files we view

for txt_file in keys[:5]:
    audio_file = tables_to_filenames[txt_file]    
    # Loop through all annotations in the file
    df = pd.read_csv(txt_file, sep='\t')
    for idx, row in df.iterrows():
        
        # Decide whether to process this call
        alpha = row['Alpha code']
        if alpha == '?':
            continue
        if alpha not in num_examples_per_sp.keys():
            num_examples_per_sp[alpha] = 1
        elif num_examples_per_sp[alpha] >= max_num_examples:
            continue
        else:
            num_examples_per_sp[alpha] += 1
        
        # Create the filename containing the info about the call
        bp_low, bp_high, approx_duration = freq_limits.query("code == @alpha")[['low_freq', 'high_freq', 'duration']].values[0]
        file_info = [str(x) for x in row[['Order', 'Family', 'Genus', 'Species', 'Alpha code', 'Begin time (s)', 'End time (s)']].tolist()]
        dirname = Path(alpha)
        dirname.mkdir(exist_ok=True)
        filename = '_'.join([Path(txt_file).stem, *file_info])
        print(filename)
        
        begin = row['Begin time (s)']
        end = row['End time (s)']
        
        # Create a longer audio segment to save
        if create_audio:
            audio_dirname = dirname.joinpath('audio')
            audio_dirname.mkdir(exist_ok=True)
            offset = begin + 3.1
            long_duration = 6
            long_segment = Audio.from_file(audio_file, offset=offset, duration=long_duration)
            if save_audio:
                audio_filename = str(audio_dirname.joinpath(filename)) + '.wav'
                long_segment.save(audio_filename)
        
        # Create a shorter spectrogram to show on website
        center = (end + begin)/2
        buffer_s = approx_duration/1.4
        offset = center - approx_duration/2 - buffer_s
        duration = approx_duration + buffer_s*2
        overlap_samples = int(window_samples*0.9)
        
        short_segment = Audio.from_file(audio_file, offset=offset, duration=duration)
        if bandpass:
            short_segment = short_segment.bandpass(bp_low, bp_high, order=order)
        
        s = Spectrogram.from_audio(
            short_segment, window_samples=window_samples, overlap_samples=overlap_samples, decibel_limits=decibel_limits, window_type=window_type)
        spectrogram_dirname = dirname.joinpath('spectrograms')
        spectrogram_dirname.mkdir(exist_ok=True)
        spectrogram_filename = str(spectrogram_dirname.joinpath(filename)) + '.jpg'
        save_spectrogram(s, filename=str(spectrogram_filename), duration=duration, save=save_spectrogram)
# Out:
# SWGH-20160919_193600_PASSERIFORMES_PARULIDAE_SETOPHAGA_STRIATA_BLPW_1635.9160000000002_1635.933
# SWGH-20160919_193600_PASSERIFORMES_PARULIDAE_SETOPHAGA_STRIATA_BLPW_1662.3039999999999_1662.336
# SWGH-20160919_193600_PASSERIFORMES_PARULIDAE_SETOPHAGA_STRIATA_BLPW_2795.034_2795.0890000000004
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_109.088_109.259
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_109.376_109.461
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_196.331_196.363
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_196.49099999999999_196.62900000000002
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_214.56_214.592
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_28680.139_28680.181
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_28680.373_28680.447999999997
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_28682.88_28682.932999999997
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_28683.051_28683.147
# SWGH-20130508_195300_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SEMIPALMATA_WILL_28683.541_28683.616
# CAWRR-20160723_213100_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SOLITARIA_SOSA_1012.622_1012.727
# CAWRR-20160723_213100_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SOLITARIA_SOSA_1012.878_1012.959
# CAWRR-20160723_213100_CHARADRIIFORMES_SCOLOPACIDAE_TRINGA_SOLITARIA_SOSA_1013.145_1013.179
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_MAGNOLIA_MAWA_1572.0839999999998_1572.1879999999999
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_MNIOTILTA_VARIA_BAWW_2192.6839999999997_2192.7529999999997
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_4272.46_4272.505999999999
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_4287.576_4287.634
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_4432.202_4432.248
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_PENSYLVANICA_CSWA_9084.993_9085.097
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_LEIOTHLYPIS_RUFICAPILLA_NAWA_9913.168_9913.214
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_FUSCA_BLBW_14291.963_14292.01
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_19064.953_19065.08
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_20045.311_20045.357
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_20055.771_20055.853
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_20068.902_20068.984
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_MAGNOLIA_MAWA_21125.701_21125.759
# CAWRR-20160723_213100_PASSERIFORMES_PARULIDAE_SETOPHAGA_MAGNOLIA_MAWA_21144.3_21144.346
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_MNIOTILTA_VARIA_BAWW_5357.909000000001_5357.973000000001
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_9354.944_9354.987
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_9580.448_9580.501
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_9686.837_9686.901
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_MAGNOLIA_MAWA_11826.698999999999_11826.763
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_13592.511999999999_13592.565
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_15323.423999999999_15323.466999999999
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_MNIOTILTA_VARIA_BAWW_17143.456000000002_17143.552
# SCST2_20170517_211600_PASSERIFORMES_PASSERELLIDAE_ZONOTRICHIA_ALBICOLLIS_WTSP_19751.125_19751.2
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_20740.171000000002_20740.224
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_MNIOTILTA_VARIA_BAWW_21514.56_21514.624
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_21682.176_21682.218999999997
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PETECHIA_YEWA_22632.293999999998_22632.338
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_MNIOTILTA_VARIA_BAWW_22802.816000000003_22802.859
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PETECHIA_YEWA_23971.275_23971.307
# SCST2_20170517_211600_PASSERIFORMES_PASSERELLIDAE_PASSERCULUS_SANDWICHENSIS_SAVS_24786.037_24786.091
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_25443.509_25443.541
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PENSYLVANICA_CSWA_25637.216_25637.248
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PENSYLVANICA_CSWA_25652.779_25652.832000000002
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PETECHIA_YEWA_25690.905_25690.952999999998
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_26546.261000000002_26546.304
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_GEOTHLYPIS_TRICHAS_COYE_26561.888_26561.941000000003
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PETECHIA_YEWA_26972.245_26972.279
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_27404.0_27404.053
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_27405.995_27406.058999999997
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_AMERICANA_NOPA_27709.888_27709.92
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_RUTICILLA_AMRE_27736.0_27736.042999999998
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_27961.877_27961.909
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SEIURUS_AUROCAPILLA_OVEN_28146.315_28146.421000000002
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_CASTANEA_BBWA_28246.526_28246.549
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_RUTICILLA_AMRE_28264.971_28265.013
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PETECHIA_YEWA_28415.381_28415.412999999997
# SCST2_20170517_211600_PASSERIFORMES_PARULIDAE_SETOPHAGA_PETECHIA_YEWA_28424.907000000003_28424.949
